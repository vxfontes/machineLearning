# %% [markdown]
# <a href="https://colab.research.google.com/github/vxfontes/machineLearning/blob/exercicios_ML/classificacao_roupa_RN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import tensorflow

dataset = keras.datasets.fashion_mnist

# %%
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(imagens_treino[1])

# %%
for imagem in range(10):
  plt.subplot(2, 5, imagem+1)
  plt.imshow(imagens_treino[imagem])
  plt.title(identificacoes_treino[imagem])
